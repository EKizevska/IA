# %% [markdown]
# <a href="https://colab.research.google.com/github/EKizevska/IA/blob/main/IA%20-%20Lab3%20-%20NN-Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораториска вежба бр.2
# Потребно е да се направи предвидување дали пациентот покажува знаци на дијабетис според критериумите на Светската Здравствена Организација (дали два часа после оптоварувањето плазмената гликоза била најмалку 200 mg / dl).
# Пациентите од податочното множество се жени над 21 година.
#
# За секој пациент дадени се карактеристиките:
# 1. Колку пати била бремена
# 2. Концентрација на плазмена гликоза после 2 часови од тестот за орална гликозна толеранција
# 3. Дијастолен крвен притисок (mm/Hg)
# 4. Дебелина на кожата на трицепсот (mm)
# 5. 2 часовен серумски инсулин
# 6. Индекс на телесни масти (тежина во kg/ (висина во m)^2)
# 7. Дали постои некој со дијабетес во фамилијата
# 8. Старост (години)
# 9. Класа (0 или 1)
#
#
# Податочното множество е зачувано: https://github.com/EKizevska/IA/blob/main/diabetes.data.txt
#
# Да се реализираат следните чекори при одработување на вежбата:
# 1. Со помош на библиотеката pandas прочитајте ја датотеката која го содржи множеството и пополнете ги вредностите кои недостасуваат во податочното множество
# 2. Прикажи статистичка анализа на податоците (средна вредност, стандардна девијација, минимална вредност, максимална вредност итн.)
# 3. Влезните и излезните податоци зачувајте ги во променливите X и Y, соодветно
# 4. Направете поделба на податоците за тренирање и тестирање со сооднос 80% према 20%. Резултатите да се зачуваат во променливите X_train, X_test, Y_train, Y_test соодветно.
# 5. Дефинирај модел со длабока невронска мрежа (Со најмалце три слоеви, за кои ќе искористиш барем две активациски функции)
# 6. Искомпалирај го моделот (истажи и избери најсоодветна loss функција: Binary Cross-Entropy, Hinge Loss, Squared Hinge Loss...) и избери метрика за евалуација на точноста
# 7. Направете тренирање (внимавај да не го претренираш) и евалуирајте ја точноста
#
# Откако ќе го истренирате вашиот модел, како ќе може да го искористите за да направите предвидувања на нови податоци?
#
# 8. Прикажи ги очекуваните и предвидените вредности од тест множеството и нумерички и графички. (помош: искористи ја функцијата predict_classes())
#
#
# *Секоја точка од барањата реализирај ја во нова ќелија.
